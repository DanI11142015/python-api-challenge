# %%
# !pip install citipy
# Out:
# Requirement already satisfied: citipy in /Users/danielleb./anaconda3/lib/python3.9/site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in /Users/danielleb./anaconda3/lib/python3.9/site-packages (from citipy) (0.16)

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import csv
import time
import scipy.stats as st
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
data =requests.get("http://api.openweathermap.org/data/2.5/forecast?id=524901&appid=b93bb814d67ba283dcb1c6a2a276cc9b")

# %%
data.json()
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1659301200,
#    'main': {'temp': 290.64,
#     'feels_like': 290.01,
#     'temp_min': 290.37,
#     'temp_max': 290.64,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1001,
#     'humidity': 60,
#     'temp_kf': 0.27},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 97},
#    'wind': {'speed': 2.76, 'deg': 59, 'gust': 6.15},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-07-31 21:00:00'},
#   {'dt': 1659312000,
#    'main': {'temp': 290.04,
#     'feels_like': 289.4,
#     'temp_min': 288.85,
#     'temp_max': 290.04,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1001,
#     'humidity': 62,
#     'temp_kf': 1.19},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 93},
#    'wind': {'speed': 1.88, 'deg': 81, 'gust': 4.28},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-08-01 00:00:00'},
#   {'dt': 1659322800,
#    'main': {'temp': 289.23,
#     'feels_like': 288.59,
#     'temp_min': 288.52,
#     'temp_max': 289.23,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1001,
#     'humidity': 65,
#     'temp_kf': 0.71},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 47},
#    'wind': {'speed': 2.28, 'deg': 78, 'gust': 4.32},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-01 03:00:00'},
#   {'dt': 1659333600,
#    'main': {'temp': 292.94,
#     'feels_like': 292.28,
#     'temp_min': 292.94,
#     'temp_max': 292.94,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1001,
#     'humidity': 50,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 53},
#    'wind': {'speed': 2.79, 'deg': 105, 'gust': 3.82},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-01 06:00:00'},
#   {'dt': 1659344400,
#    'main': {'temp': 296.32,
#     'feels_like': 295.74,
#     'temp_min': 296.32,
#     'temp_max': 296.32,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1001,
#     'humidity': 40,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.62, 'deg': 140, 'gust': 2.77},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-01 09:00:00'},
#   {'dt': 1659355200,
#    'main': {'temp': 296.92,
#     'feels_like': 296.34,
#     'temp_min': 296.92,
#     'temp_max': 296.92,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1001,
#     'humidity': 38,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.25, 'deg': 147, 'gust': 2.26},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-01 12:00:00'},
#   {'dt': 1659366000,
#    'main': {'temp': 297.26,
#     'feels_like': 296.72,
#     'temp_min': 297.26,
#     'temp_max': 297.26,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1000,
#     'humidity': 38,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 2.34, 'deg': 137, 'gust': 2.47},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-01 15:00:00'},
#   {'dt': 1659376800,
#    'main': {'temp': 293.44,
#     'feels_like': 292.88,
#     'temp_min': 293.44,
#     'temp_max': 293.44,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1000,
#     'humidity': 52,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 55},
#    'wind': {'speed': 1.83, 'deg': 141, 'gust': 2.46},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-08-01 18:00:00'},
#   {'dt': 1659387600,
#    'main': {'temp': 291.52,
#     'feels_like': 290.95,
#     'temp_min': 291.52,
#     'temp_max': 291.52,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1000,
#     'humidity': 59,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 87},
#    'wind': {'speed': 2.28, 'deg': 101, 'gust': 4.85},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-08-01 21:00:00'},
#   {'dt': 1659398400,
#    'main': {'temp': 289.8,
#     'feels_like': 289.14,
#     'temp_min': 289.8,
#     'temp_max': 289.8,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1000,
#     'humidity': 62,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 82},
#    'wind': {'speed': 2.15, 'deg': 109, 'gust': 5.18},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-08-02 00:00:00'},
#   {'dt': 1659409200,
#    'main': {'temp': 289.54,
#     'feels_like': 288.88,
#     'temp_min': 289.54,
#     'temp_max': 289.54,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1000,
#     'humidity': 63,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.07, 'deg': 122, 'gust': 4.51},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-02 03:00:00'},
#   {'dt': 1659420000,
#    'main': {'temp': 294.04,
#     'feels_like': 293.46,
#     'temp_min': 294.04,
#     'temp_max': 294.04,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1000,
#     'humidity': 49,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.45, 'deg': 146, 'gust': 3.94},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-02 06:00:00'},
#   {'dt': 1659430800,
#    'main': {'temp': 298.13,
#     'feels_like': 297.65,
#     'temp_min': 298.13,
#     'temp_max': 298.13,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1000,
#     'humidity': 37,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 52},
#    'wind': {'speed': 3.24, 'deg': 153, 'gust': 4.07},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-02 09:00:00'},
#   {'dt': 1659441600,
#    'main': {'temp': 299,
#     'feels_like': 298.55,
#     'temp_min': 299,
#     'temp_max': 299,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 999,
#     'humidity': 35,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 66},
#    'wind': {'speed': 3.35, 'deg': 159, 'gust': 3.46},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-02 12:00:00'},
#   {'dt': 1659452400,
#    'main': {'temp': 298.45,
#     'feels_like': 298.05,
#     'temp_min': 298.45,
#     'temp_max': 298.45,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 999,
#     'humidity': 39,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 60},
#    'wind': {'speed': 2.96, 'deg': 165, 'gust': 2.89},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-02 15:00:00'},
#   {'dt': 1659463200,
#    'main': {'temp': 294.62,
#     'feels_like': 294.21,
#     'temp_min': 294.62,
#     'temp_max': 294.62,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 999,
#     'humidity': 53,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 40},
#    'wind': {'speed': 1.71, 'deg': 172, 'gust': 2.2},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-08-02 18:00:00'},
#   {'dt': 1659474000,
#    'main': {'temp': 292.92,
#     'feels_like': 292.44,
#     'temp_min': 292.92,
#     'temp_max': 292.92,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 999,
#     'humidity': 57,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 53},
#    'wind': {'speed': 0.42, 'deg': 169, 'gust': 0.55},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-08-02 21:00:00'},
#   {'dt': 1659484800,
#    'main': {'temp': 291.45,
#     'feels_like': 290.95,
#     'temp_min': 291.45,
#     'temp_max': 291.45,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1000,
#     'humidity': 62,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 64},
#    'wind': {'speed': 1.15, 'deg': 90, 'gust': 1.18},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-08-03 00:00:00'},
#   {'dt': 1659495600,
#    'main': {'temp': 291.06,
#     'feels_like': 290.6,
#     'temp_min': 291.06,
#     'temp_max': 291.06,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1000,
#     'humidity': 65,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 86},
#    'wind': {'speed': 1.59, 'deg': 98, 'gust': 2.61},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-03 03:00:00'},
#   {'dt': 1659506400,
#    'main': {'temp': 295.66,
#     'feels_like': 295.25,
#     'temp_min': 295.66,
#     'temp_max': 295.66,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1000,
#     'humidity': 49,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 91},
#    'wind': {'speed': 1.29, 'deg': 129, 'gust': 1.79},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-03 06:00:00'},
#   {'dt': 1659517200,
#    'main': {'temp': 299.78,
#     'feels_like': 299.78,
#     'temp_min': 299.78,
#     'temp_max': 299.78,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1000,
#     'humidity': 36,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 71},
#    'wind': {'speed': 1.51, 'deg': 127, 'gust': 2.09},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-03 09:00:00'},
#   {'dt': 1659528000,
#    'main': {'temp': 300.98,
#     'feels_like': 300.27,
#     'temp_min': 300.98,
#     'temp_max': 300.98,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1000,
#     'humidity': 33,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 72},
#    'wind': {'speed': 1.85, 'deg': 160, 'gust': 2.01},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-03 12:00:00'},
#   {'dt': 1659538800,
#    'main': {'temp': 300.3,
#     'feels_like': 299.93,
#     'temp_min': 300.3,
#     'temp_max': 300.3,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1000,
#     'humidity': 36,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 79},
#    'wind': {'speed': 1.71, 'deg': 190, 'gust': 1.96},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-03 15:00:00'},
#   {'dt': 1659549600,
#    'main': {'temp': 297.16,
#     'feels_like': 296.84,
#     'temp_min': 297.16,
#     'temp_max': 297.16,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1000,
#     'humidity': 47,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 90},
#    'wind': {'speed': 1.62, 'deg': 281, 'gust': 2.49},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-08-03 18:00:00'},
#   {'dt': 1659560400,
#    'main': {'temp': 295.81,
#     'feels_like': 295.46,
#     'temp_min': 295.81,
#     'temp_max': 295.81,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1001,
#     'humidity': 51,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 98},
#    'wind': {'speed': 1.4, 'deg': 335, 'gust': 2.26},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-08-03 21:00:00'},
#   {'dt': 1659571200,
#    'main': {'temp': 294.27,
#     'feels_like': 293.93,
#     'temp_min': 294.27,
#     'temp_max': 294.27,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1001,
#     'humidity': 57,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 94},
#    'wind': {'speed': 1.44, 'deg': 351, 'gust': 2.01},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-08-04 00:00:00'},
#   {'dt': 1659582000,
#    'main': {'temp': 293.61,
#     'feels_like': 293.3,
#     'temp_min': 293.61,
#     'temp_max': 293.61,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1002,
#     'humidity': 61,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 47},
#    'wind': {'speed': 1.27, 'deg': 38, 'gust': 1.83},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-04 03:00:00'},
#   {'dt': 1659592800,
#    'main': {'temp': 297.9,
#     'feels_like': 297.61,
#     'temp_min': 297.9,
#     'temp_max': 297.9,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1002,
#     'humidity': 45,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 48},
#    'wind': {'speed': 1.11, 'deg': 61, 'gust': 1.48},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-04 06:00:00'},
#   {'dt': 1659603600,
#    'main': {'temp': 301.82,
#     'feels_like': 300.93,
#     'temp_min': 301.82,
#     'temp_max': 301.82,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1002,
#     'humidity': 33,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 15},
#    'wind': {'speed': 1.6, 'deg': 63, 'gust': 2.26},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-04 09:00:00'},
#   {'dt': 1659614400,
#    'main': {'temp': 303.14,
#     'feels_like': 301.82,
#     'temp_min': 303.14,
#     'temp_max': 303.14,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1002,
#     'humidity': 29,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 11},
#    'wind': {'speed': 1.64, 'deg': 122, 'gust': 2.4},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-04 12:00:00'},
#   {'dt': 1659625200,
#    'main': {'temp': 301.07,
#     'feels_like': 300.62,
#     'temp_min': 301.07,
#     'temp_max': 301.07,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1002,
#     'humidity': 38,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 64},
#    'wind': {'speed': 3.06, 'deg': 144, 'gust': 3.28},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-04 15:00:00'},
#   {'dt': 1659636000,
#    'main': {'temp': 298.54,
#     'feels_like': 298.34,
#     'temp_min': 298.54,
#     'temp_max': 298.54,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1003,
#     'humidity': 46,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 81},
#    'wind': {'speed': 1.88, 'deg': 41, 'gust': 2.86},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-08-04 18:00:00'},
#   {'dt': 1659646800,
#    'main': {'temp': 297,
#     'feels_like': 296.82,
#     'temp_min': 297,
#     'temp_max': 297,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1003,
#     'humidity': 53,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.49, 'deg': 96, 'gust': 2.82},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-08-04 21:00:00'},
#   {'dt': 1659657600,
#    'main': {'temp': 295.85,
#     'feels_like': 295.66,
#     'temp_min': 295.85,
#     'temp_max': 295.85,
#     'pressure': 1021,
#     'sea_level': 1021,
#     'grnd_level': 1004,
#     'humidity': 57,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 1.36, 'deg': 106, 'gust': 1.98},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-08-05 00:00:00'},
#   {'dt': 1659668400,
#    'main': {'temp': 294.6,
#     'feels_like': 294.42,
#     'temp_min': 294.6,
#     'temp_max': 294.6,
#     'pressure': 1021,
#     'sea_level': 1021,
#     'grnd_level': 1004,
#     'humidity': 62,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 77},
#    'wind': {'speed': 1.29, 'deg': 75, 'gust': 1.77},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-05 03:00:00'},
#   {'dt': 1659679200,
#    'main': {'temp': 298.77,
#     'feels_like': 298.61,
#     'temp_min': 298.77,
#     'temp_max': 298.77,
#     'pressure': 1021,
#     'sea_level': 1021,
#     'grnd_level': 1004,
#     'humidity': 47,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 55},
#    'wind': {'speed': 1.54, 'deg': 84, 'gust': 2.06},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-05 06:00:00'},
#   {'dt': 1659690000,
#    'main': {'temp': 302.62,
#     'feels_like': 301.79,
#     'temp_min': 302.62,
#     'temp_max': 302.62,
#     'pressure': 1021,
#     'sea_level': 1021,
#     'grnd_level': 1004,
#     'humidity': 35,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 11},
#    'wind': {'speed': 1.59, 'deg': 106, 'gust': 2.01},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-05 09:00:00'},
#   {'dt': 1659700800,
#    'main': {'temp': 303.01,
#     'feels_like': 302,
#     'temp_min': 303.01,
#     'temp_max': 303.01,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1003,
#     'humidity': 33,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 34},
#    'wind': {'speed': 1.56, 'deg': 156, 'gust': 1.68},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-05 12:00:00'},
#   {'dt': 1659711600,
#    'main': {'temp': 301.43,
#     'feels_like': 300.85,
#     'temp_min': 301.43,
#     'temp_max': 301.43,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1002,
#     'humidity': 37,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 91},
#    'wind': {'speed': 1.62, 'deg': 198, 'gust': 2.43},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-05 15:00:00'},
#   {'dt': 1659722400,
#    'main': {'temp': 298.66,
#     'feels_like': 298.49,
#     'temp_min': 298.66,
#     'temp_max': 298.66,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1003,
#     'humidity': 47,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 89},
#    'wind': {'speed': 1.12, 'deg': 280, 'gust': 1.87},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-08-05 18:00:00'}],
#  'city': {'id': 524901,
#   'name': 'Moscow',
#   'coord': {'lat': 55.7522, 'lon': 37.6156},
#   'country': 'RU',
#   'population': 0,
#   'timezone': 10800,
#   'sunrise': 1659231144,
#   'sunset': 1659289159}}

# %%
citipy.cities()
